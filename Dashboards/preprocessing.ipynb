# %% [markdown]
# **1. Preprocessing for data visualization** ✔

# %%
import pandas as pd

df1 = pd.read_csv("/content/World Energy Consumption.csv")
df1
# Out:
#              country  year iso_code  population           gdp  \
# 0      ASEAN (Ember)  2000      NaN         NaN           NaN
# 1      ASEAN (Ember)  2001      NaN         NaN           NaN
# 2      ASEAN (Ember)  2002      NaN         NaN           NaN
# 3      ASEAN (Ember)  2003      NaN         NaN           NaN
# 4      ASEAN (Ember)  2004      NaN         NaN           NaN
# ...              ...   ...      ...         ...           ...
# 22007       Zimbabwe  2018      ZWE  15052191.0  2.271535e+10
# 22008       Zimbabwe  2019      ZWE  15354606.0           NaN
# 22009       Zimbabwe  2020      ZWE  15669663.0           NaN
# 22010       Zimbabwe  2021      ZWE  15993525.0           NaN
# 22011       Zimbabwe  2022      ZWE  16320539.0           NaN
#
#        biofuel_cons_change_pct  biofuel_cons_change_twh  \
# 0                          NaN                      NaN
# 1                          NaN                      NaN
# ...

# %%
df1 = df1[['iso_code',
           'country',
           'year',
           'biofuel_electricity',
           'hydro_electricity',
           'nuclear_electricity',
           'solar_electricity',
           'wind_electricity',
           'other_renewable_electricity',
           'coal_electricity',
           'gas_electricity',
           'oil_electricity',
           'biofuel_elec_per_capita',
           'hydro_elec_per_capita',
           'nuclear_elec_per_capita',
           'solar_elec_per_capita',
           'wind_elec_per_capita',
           'coal_elec_per_capita',
           'gas_elec_per_capita',
           'oil_elec_per_capita',
           'population'
          ]]
df1
# Out:
#       iso_code        country  year  biofuel_electricity  hydro_electricity  \
# 0          NaN  ASEAN (Ember)  2000                 5.60              50.37
# 1          NaN  ASEAN (Ember)  2001                 6.02              54.26
# 2          NaN  ASEAN (Ember)  2002                 6.06              53.32
# 3          NaN  ASEAN (Ember)  2003                 6.69              53.28
# 4          NaN  ASEAN (Ember)  2004                 7.57              52.88
# ...        ...            ...   ...                  ...                ...
# 22007      ZWE       Zimbabwe  2018                 0.39               5.05
# 22008      ZWE       Zimbabwe  2019                 0.38               4.17
# 22009      ZWE       Zimbabwe  2020                 0.35               3.81
# 22010      ZWE       Zimbabwe  2021                 0.38               4.00
# 22011      ZWE       Zimbabwe  2022                  NaN                NaN
#
# ...

# %%
#loc for data verification

df1.loc[(df1['country'] == 'Brazil') & (df1['year'] == 2020)]
# Out:
#      iso_code country  year  biofuel_electricity  hydro_electricity  \
# 2973      BRA  Brazil  2020                56.56             396.33
#
#       nuclear_electricity  solar_electricity  wind_electricity  \
# 2973                13.21              10.64             56.48
#
#       other_renewable_electricity  coal_electricity  ...  oil_electricity  \
# 2973                        56.56             19.53  ...            10.14
#
#       biofuel_elec_per_capita  hydro_elec_per_capita  nuclear_elec_per_capita  \
# 2973                  265.295               1858.991                   61.962
#
#       solar_elec_per_capita  wind_elec_per_capita  coal_elec_per_capita  \
# 2973                 49.907                264.92                91.606
#
#       gas_elec_per_capita  oil_elec_per_capita   population
# 2973              241.468               47.562  213196304.0
#
# [1 rows x 21 columns]

# %%
df2 = df1.melt(id_vars=['iso_code', 'country', 'year', 'population'],
              var_name='fuel',
              value_name='production'
)

df2
# Out:
#        iso_code        country  year  population                 fuel  \
# 0           NaN  ASEAN (Ember)  2000         NaN  biofuel_electricity
# 1           NaN  ASEAN (Ember)  2001         NaN  biofuel_electricity
# 2           NaN  ASEAN (Ember)  2002         NaN  biofuel_electricity
# 3           NaN  ASEAN (Ember)  2003         NaN  biofuel_electricity
# 4           NaN  ASEAN (Ember)  2004         NaN  biofuel_electricity
# ...         ...            ...   ...         ...                  ...
# 374199      ZWE       Zimbabwe  2018  15052191.0  oil_elec_per_capita
# 374200      ZWE       Zimbabwe  2019  15354606.0  oil_elec_per_capita
# 374201      ZWE       Zimbabwe  2020  15669663.0  oil_elec_per_capita
# 374202      ZWE       Zimbabwe  2021  15993525.0  oil_elec_per_capita
# 374203      ZWE       Zimbabwe  2022  16320539.0  oil_elec_per_capita
#
#         production
# 0            5.600
# 1            6.020
# 2            6.060
# 3            6.690
# 4            7.570
# ...

# %%
def split_type(row):
    if row['fuel'].find('per_capita') != -1:
        value = row['production']
    else:
        value = 0
    return value

df2['per_capita'] = df2.apply(split_type, axis=1)

df2
# Out:
#        iso_code        country  year  population                 fuel  \
# 0           NaN  ASEAN (Ember)  2000         NaN  biofuel_electricity
# 1           NaN  ASEAN (Ember)  2001         NaN  biofuel_electricity
# 2           NaN  ASEAN (Ember)  2002         NaN  biofuel_electricity
# 3           NaN  ASEAN (Ember)  2003         NaN  biofuel_electricity
# 4           NaN  ASEAN (Ember)  2004         NaN  biofuel_electricity
# ...         ...            ...   ...         ...                  ...
# 374199      ZWE       Zimbabwe  2018  15052191.0  oil_elec_per_capita
# 374200      ZWE       Zimbabwe  2019  15354606.0  oil_elec_per_capita
# 374201      ZWE       Zimbabwe  2020  15669663.0  oil_elec_per_capita
# 374202      ZWE       Zimbabwe  2021  15993525.0  oil_elec_per_capita
# 374203      ZWE       Zimbabwe  2022  16320539.0  oil_elec_per_capita
#
#         production  per_capita
# 0            5.600       0.000
# 1            6.020       0.000
# ...

# %%
#Clean percapita from production
def clean_production(row):
    if row['per_capita'] != 0:
        value = 0
    else:
        value = row['production']
    return value


df2['production'] = df2.apply(clean_production, axis=1)

df2
# Out:
#        iso_code        country  year  population                 fuel  \
# 0           NaN  ASEAN (Ember)  2000         NaN  biofuel_electricity
# 1           NaN  ASEAN (Ember)  2001         NaN  biofuel_electricity
# 2           NaN  ASEAN (Ember)  2002         NaN  biofuel_electricity
# 3           NaN  ASEAN (Ember)  2003         NaN  biofuel_electricity
# 4           NaN  ASEAN (Ember)  2004         NaN  biofuel_electricity
# ...         ...            ...   ...         ...                  ...
# 374199      ZWE       Zimbabwe  2018  15052191.0  oil_elec_per_capita
# 374200      ZWE       Zimbabwe  2019  15354606.0  oil_elec_per_capita
# 374201      ZWE       Zimbabwe  2020  15669663.0  oil_elec_per_capita
# 374202      ZWE       Zimbabwe  2021  15993525.0  oil_elec_per_capita
# 374203      ZWE       Zimbabwe  2022  16320539.0  oil_elec_per_capita
#
#         production  per_capita
# 0             5.60       0.000
# 1             6.02       0.000
# ...

# %%
#Clean name 'fuel'

df2['fuel'] = df2['fuel'].str.replace('_elec_per_capita', '')
df2['fuel'] = df2['fuel'].str.replace('_electricity', '')

df2['fuel'].unique()
# Out:
# array(['biofuel', 'hydro', 'nuclear', 'solar', 'wind', 'other_renewable',
#        'coal', 'gas', 'oil'], dtype=object)

# %%
#Final window

df_final = df2.groupby(['iso_code', 'country', 'year', 'population', 'fuel']).sum().reset_index()

df_final.loc[(df_final['country'] == 'Brazil') & (df_final['year'] == 2018)]
# Out:
#       iso_code country  year   population             fuel  production  \
# 19755      BRA  Brazil  2018  210166592.0          biofuel       52.13
# 19756      BRA  Brazil  2018  210166592.0             coal       22.68
# 19757      BRA  Brazil  2018  210166592.0              gas       52.36
# 19758      BRA  Brazil  2018  210166592.0            hydro      388.97
# 19759      BRA  Brazil  2018  210166592.0          nuclear       14.79
# 19760      BRA  Brazil  2018  210166592.0              oil       11.65
# 19761      BRA  Brazil  2018  210166592.0  other_renewable       52.13
# 19762      BRA  Brazil  2018  210166592.0            solar        3.44
# 19763      BRA  Brazil  2018  210166592.0             wind       48.12
#
#        per_capita
# 19755     248.041
# 19756     107.914
# 19757     249.136
# 19758    1850.770
# 19759      70.373
# 19760      55.432
# 19761       0.000
# 19762      16.368
# 19763     228.961

# %%
df_final.to_csv('rwenergy_dataset.csv',index=False)
